# %% [markdown]
# <a href="https://colab.research.google.com/github/ksumi0712-ui/temp-public/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("나는 김수미")
# Out:
# 나는 김수미
